# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/laukamkit/capstone_project_GroupA.git

# %%
# %cd capstone_project_GroupA
# !git checkout main

# %%
# %cd src

# %%
SAVE_PATH = '/content/drive/MyDrive/Colab Notebooks/capstone_project_GroupA/lstm_tuning'

# %% [markdown]
# Run from here if not using Colab.
#
# **Do not use specific_output_dir**

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from datetime import datetime
from ModelFiles.LSTM.LSTMUtils import *
from ModelFiles.ModelConfigs import LSTMConfig, SEEDS
from ModelFiles.ModelEnums import LSTMModelType
from ModelFiles.ModelPlots import *

use_log_target = True
EVAL_STEP_SIZE = 48
FORECAST_LAST_STEP_ONLY = [False]
NUM_EPOCHS = 100
PATIENCE = 10
DEBUG = False
HORIZON_LOOKBACK = [(48, 168), (336, 336), (720, 720)]
# hidden_size, num_layers, dropout, learning_rate, num_attention_heads, batch_size
HYPERPARAMETER_COMBINATIONS = [(128, 2, 0.2, 0.00001, 4, 64), (256, 4, 0.35, 0.00001, 8, 64)]
SEEDS = [31415] # run once first to see preliminary results.
for horizon, lookback in HORIZON_LOOKBACK:
    for hidden_size, num_layers, dropout, learning_rate, num_attention_heads, batch_size in HYPERPARAMETER_COMBINATIONS:
        for forecast_last_step_only in FORECAST_LAST_STEP_ONLY:
            for seed in SEEDS:
                biLSTM_config = LSTMConfig(
                    task_id= f"biLSTM_{datetime.now().strftime('%Y%m%d_%H%M%S')}",
                    model_type= LSTMModelType.BILSTM,
                    hidden_size= hidden_size,
                    num_layers= num_layers,
                    dropout= dropout,
                    learning_rate= learning_rate,
                    batch_size= batch_size,
                    training_epochs= NUM_EPOCHS,
                    patience= PATIENCE,
                    use_mlp_head= True,
                    mlp_hidden_size= 64,
                    target_col= "TOTALDEMAND" if not use_log_target else "LOG_TOTALDEMAND",
                    used_log_target= use_log_target,
                    target_lags= [48, 336],
                    target_mas= [],
                    feature_cols= ["TEMPERATURE"],
                    feature_lag_cols= [],
                    lookback_window= lookback,
                    forecast_horizon= horizon,
                    forecast_last_step_only=forecast_last_step_only,
                    num_attention_heads= num_attention_heads,
                    weight_decay= 1e-4,
                    scale=True,
                    seed=seed,
                    save_training_log= True,
                    save_test_results= False,
                    eval_step_size=EVAL_STEP_SIZE,
                    debug= DEBUG,
                    save_model=False
                )
                runs_df_artifact = run_experiment(config=biLSTM_config, experiment_name=biLSTM_config.task_id, specific_output_dir=SAVE_PATH)
                print("=" * 200)
                print("\n")
# Out:
# Found NSW data path: C:\Users\kyim1\Desktop\capstone_project_GroupA\data\NSW
# Set random seed to 31415
# Use GPU: cuda:0
#
# ==========================================================================================
# Running experiment: biLSTM_20260417_223533
# ==========================================================================================
# task_id: biLSTM_20260417_223533
# forecast_horizon: 48
# lookback_window: 168
# date_col: DATETIME
# target_col: LOG_TOTALDEMAND
# used_log_target: True
# target_lags: [48, 336]
# target_mas: []
# feature_cols: ['TEMPERATURE']
# feature_lag_cols: []
# scale: True
# seed: 31415
# eval_step_size: 48
# save_training_log: True
# save_test_results: False
# save_model: False
# debug: False
# training_epochs: 1
# batch_size: 64
# learning_rate: 1e-05
# patience: 10
# num_attention_heads: 4
# dropout: 0.2
# use_gpu: True
# gpu: 0
# num_workers: 0
# time_encoding: timeF
# model_type: LSTMModelType.BILSTM
# hidden_size: 128
# num_layers: 2
# use_mlp_head: True
# mlp_hidden_size: 64
# weight_decay: 0.0001
# scheduler: None
# optimizer: adam
# scheduler_factor: 0.5
# scheduler_patience: 5
# scheduler_step_size: 10
# scheduler_gamma: 0.5
# forecast_last_step_only: False
# train 124744
# val 17852
# test 35752
#
# ============================================================
# DEBUG: FEATURE INSPECTION
# ============================================================
#
# Feature names:
# 0: LOG_TOTALDEMAND
# 1: TEMPERATURE
# 2: LOG_TOTALDEMAND_lag_48
# 3: LOG_TOTALDEMAND_lag_336
#
# Sequence shape (lookback, num_features): torch.Size([168, 4])
#
# Raw sequence values (first 5 timesteps):
# tensor([[-0.0021, -0.1797, -0.0170, -0.1345],
#         [-0.0191, -0.4040, -0.2180, -0.3170],
#         [ 0.0833, -0.4379, -0.2576, -0.3107],
#         [ 0.1003, -0.5632, -0.3934, -0.4358],
#         [ 0.0833, -0.5358, -0.4270, -0.4378]])
#
# Target (scaled): -0.048004984855651855
# Target (real scale): 9.205765724182129
# ============================================================
#
#
# Sequence shapes:
# X_train: (124959, 4) | y_train: (124959, 1)
# X_val:   (18067, 4) | y_val:   (18067, 1)
# X_test:  (35967, 4) | y_test:  (35967, 1)
# [DEBUG] First parameter tensor: lstm.weight_ih_l0
# [DEBUG] First 5 values: [-3.0129284e-02 -5.1033016e-02  6.0915045e-02  7.4858330e-02
#   3.8824975e-05]
# [DEBUG] First 5 y values from first train batch: tensor([[-0.6268],
#         [-0.8673],
#         [-1.0067],
#         [-1.1028],
#         [-1.1667]])
# train 124744
# val 17852
# Epoch [1/1] | Train Loss: 0.861037 | Val Loss: 0.579856
# Saved biLSTM_20260417_223533_fitting_log.csv to /content/drive/MyDrive/Colab Notebooks/capstone_project_GroupA/lstm_tuning\LSTM_results\biLSTM_20260417_223533_fitting_log.csv
# test 35752
# Saved biLSTM_20260417_223533_test_metrics.csv to /content/drive/MyDrive/Colab Notebooks/capstone_project_GroupA/lstm_tuning\LSTM_results\biLSTM_20260417_223533_test_metrics.csv
# ========================================================================================================================================================================================================
